# %%
# Week 1: Data Cleaning - Omnichannel Retail Sales
# Infotact Technical Internship Program - Project 1
# Intern: Akhila

import pandas as pd
import numpy as np

# Step 1: Load dataset as per project spec: order_id, product, quantity, price
data = {
    'order_id': [1001, 1002, 1003, 1004, 1005, 1006],
    'product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Laptop', None],
    'quantity': [1, 2, 1, 1, 1, 3],
    'price': [55000, 800, 1500, 12000, 55000, 2500],
    'order_date': ['2024-01-15', '2024-01-16', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19'],
    'city': ['Hyderabad', 'Bangalore', 'Chennai', 'Hyderabad', 'Mumbai', 'Delhi'],
    'channel': ['Online', 'POS', 'Online', 'POS', 'Online', 'POS']
}

df = pd.DataFrame(data)
print("=== Dataset Loaded ===")
print(df.head())
print("\n=== Dataset Info ===")
df.info()

# Step 2: Check for NULL values - Mandatory per Infotact spec
print("\n=== NULL Values Check ===")
print(df.isnull().sum())
# Out:
# === Dataset Loaded ===
#    order_id   product  quantity  price  order_date       city channel
# 0      1001    Laptop         1  55000  2024-01-15  Hyderabad  Online
# 1      1002     Mouse         2    800  2024-01-16  Bangalore     POS
# 2      1003  Keyboard         1   1500  2024-01-16    Chennai  Online
# 3      1004   Monitor         1  12000  2024-01-17  Hyderabad     POS
# 4      1005    Laptop         1  55000  2024-01-18     Mumbai  Online
#
# === Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    6 non-null      int64
#  1   product     5 non-null      object
#  2   quantity    6 non-null      int64
#  3   price       6 non-null      int64
#  4   order_date  6 non-null      object
#  5   city        6 non-null      object
#  6   channel     6 non-null      object
# dtypes: int64(3), object(4)
# memory usage: 468.0+ bytes
#
# === NULL Values Check ===
# order_id      0
# product       1
# quantity      0
# price         0
# order_date    0
# city          0
# channel       0
# dtype: int64

# %%
print("\n=== Fixing NULL Values ===")
df['product'].fillna('Unknown Product', inplace=True)
print("\n=== After Fix - NULL Values Check ===")
print(df.isnull().sum())
# Out:
# === Fixing NULL Values ===
#
# === After Fix - NULL Values Check ===
# order_id      0
# product       0
# quantity      0
# price         0
# order_date    0
# city          0
# channel       0
# dtype: int64
# /tmp/ipykernel_24916/165644922.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product'].fillna('Unknown Product', inplace=True)
